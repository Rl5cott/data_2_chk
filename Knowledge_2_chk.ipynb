# %%
# Knowledge check 1 for DA2
import pandas as pd
import _json
import requests
import numpy
r = requests.get('https://api.publicapis.org/entries')
data = r.json()
entries = data

# %%
df = pd.json_normalize(entries, 'entries')

# %%
df.head (10)
# Out:
#          API                                        Description    Auth  \
# 0  AdoptAPet                  Resource to help get pets adopted  apiKey
# 1    Axolotl           Collection of axolotl pictures and facts
# 2  Cat Facts                                    Daily cat facts
# 3     Cataas          Cat as a service (cats pictures and gifs)
# 4       Cats                       Pictures of cats from Tumblr  apiKey
# 5  Dog Facts                                   Random dog facts
# 6  Dog Facts                               Random facts of Dogs
# 7       Dogs                 Based on the Stanford Dogs Dataset
# 8      eBird  Retrieve recent or notable birding observation...  apiKey
# 9  FishWatch  Information and pictures about individual fish...
#
#    HTTPS Cors                                               Link Category
# 0   True  yes  https://www.adoptapet.com/public/apis/pet_list...  Animals
# 1   True   no                 https://theaxolotlapi.netlify.app/  Animals
# ...

# %%
df.describe()
# Out:
#             API Description  Auth HTTPS     Cors  \
# count      1425        1425  1425  1425     1425
# unique     1412        1371     5     2        4
# top     Numbers       Music        True  unknown
# freq          2           9   669  1333      915
#
#                                                      Link     Category
# count                                                1425         1425
# unique                                               1425           51
# top     https://www.adoptapet.com/public/apis/pet_list...  Development
# freq                                                    1          120

# %%
df.count()
# Out:
# API            1425
# Description    1425
# Auth           1425
# HTTPS          1425
# Cors           1425
# Link           1425
# Category       1425
# dtype: int64

# %%
df.iloc[4:10]
# Out:
#          API                                        Description    Auth  \
# 4       Cats                       Pictures of cats from Tumblr  apiKey
# 5  Dog Facts                                   Random dog facts
# 6  Dog Facts                               Random facts of Dogs
# 7       Dogs                 Based on the Stanford Dogs Dataset
# 8      eBird  Retrieve recent or notable birding observation...  apiKey
# 9  FishWatch  Information and pictures about individual fish...
#
#    HTTPS Cors                                               Link Category
# 4   True   no                        https://docs.thecatapi.com/  Animals
# 5   True  yes           https://dukengn.github.io/Dog-facts-API/  Animals
# 6   True  yes                 https://kinduff.github.io/dog-api/  Animals
# 7   True  yes                           https://dog.ceo/dog-api/  Animals
# 8   True   no  https://documenter.getpostman.com/view/664302/...  Animals
# ...

# %%
df[df.Description.str.contains('null')].head()
# Out:
# Empty DataFrame
# Columns: [API, Description, Auth, HTTPS, Cors, Link, Category]
# Index: []

# %%
df[df.HTTPS.str.comtains('null')].head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 df[df.HTTPS.str.comtains('null')].head()
#
# File c:\Users\rl5co\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# File c:\Users\rl5co\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\accessor.py:182, in CachedAccessor.__get__(self, obj, cls)
#     179 if obj is None:
#     180     # we're accessing the attribute of the class, i.e., Dataset.geo
#     181     return self._accessor
# ...
